# %%
# !pwd
# Out:
# /home/sraj/Documents/10_Sem/Exp-HEP/Term_paper/codes

# %%
# !clear

# %%
ls
# Out:
# Untitled.ipynb

# %%
# %matplotlib inline
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np

# %%
theta = np.pi/3
t = 2*theta
dm = 1
E = 40
L =  np.linspace(0,600,100)

# %%
P= ((np.sin(t))**2)*(np.sin(1.27* dm* (L/40))**2)

# %%
P;

# %%
plt.plot(L,P, color = 'blue', alpha = 1, linewidth = 1.2)

# %%
P= ((np.sin(t))**2)*(np.sin(1.27* dm* (L/40))**2)

# %%
theta_1 = (15, 30, 45, 120)

# %%
theta_1
# Out:
# (15, 30, 45, 120)

# %%
for t in theta_1:
    plt.plot( ((np.sin(t))**2)*(np.sin(1.27* dm* (L/40))**2))

# %%
theta_1 = np.pi/3
t = 2*theta_1
dm = 1
E = 40
L =  np.linspace(0,600,100)

# %%
P_1= 1 -((np.sin(t))**2)*(np.sin(1.27* dm* (L/40))**2)
P_2 = ((np.sin(t))**2)*(np.sin(1.27* dm* (L/40))**2)

# %%
plt.plot(L, P_1)
plt.plot(L, P_2)

# %%
theta_1 = np.pi/10
t = 2*theta_1

# %%
P_1= 1 -((np.sin(t))**2)*(np.sin(1.27* dm* (L/40))**2)
P_2 = ((np.sin(t))**2)*(np.sin(1.27* dm* (L/40))**2)

# %%
plt.plot(L, P_1)
plt.plot(L, P_2)

# %%
theta_1 = np.pi/4
t = 2*theta_1

# %%
P_1= 1 -((np.sin(t))**2)*(np.sin(1.27* dm* (L/40))**2)
P_2 = ((np.sin(t))**2)*(np.sin(1.27* dm* (L/40))**2)

# %%
plt.plot(L, P_1)
plt.plot(L, P_2)

# %%
theta = np.pi/3
t = 2*theta
dm = 1
E = 40
L =  np.linspace(0,600,100)

# %%
P_11= ((np.sin(t))**2)*(np.sin(1.27* dm* (L/20))**2)
P_22 = ((np.sin(t))**2)*(np.sin(1.27* dm* (L/80))**2)

# %%
plt.plot(L, P_11, 'red')
plt.plot(L, P_22, 'black')

# %%
#for L =10Km
theta = np.pi/3
t = 2*theta
dm = 1
E = np.linspace(0,10, 10000)

# %%
P_10= ((np.sin(t))**2)*(np.sin(1.27* dm* (10/E))**2)
# Out:
# /tmp/ipykernel_57632/782406678.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   P_10= ((np.sin(t))**2)*(np.sin(1.27* dm* (10/E))**2)
# /tmp/ipykernel_57632/782406678.py:1: RuntimeWarning: invalid value encountered in sin
#   P_10= ((np.sin(t))**2)*(np.sin(1.27* dm* (10/E))**2)

# %%
plt.plot(E, P_10, 'c')

# %%
P= ((np.sin(t))**2)*(np.sin(1.27* dm* (100/E))**2)
# Out:
# /tmp/ipykernel_57632/4074840770.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   P= ((np.sin(t))**2)*(np.sin(1.27* dm* (100/E))**2)
# /tmp/ipykernel_57632/4074840770.py:1: RuntimeWarning: invalid value encountered in sin
#   P= ((np.sin(t))**2)*(np.sin(1.27* dm* (100/E))**2)

# %%
plt.plot(E, P, 'g' , alpha = 0.7)

# %%
dm_1  = np.sqrt(0.1)
dm_2 = np.sqrt(0.01)
L =  np.linspace(0,10000,1000)

# %%
P_dm_1= ((np.sin(t))**2)*(np.sin(1.27* dm_1* (L/40))**2)
P_dm_2 = ((np.sin(t))**2)*(np.sin(1.27* dm_2* (L/40))**2)

# %%
plt.plot(L, P_dm_1)
plt.plot(L, P_dm_2)

# %% [markdown]
# # Three Flavor Oscillation

# %% [markdown]
# ## The V_e --> V_e channel

# %%
#define Parameters
import ROOT
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_57632/2507142381.py in <module>
#       1 #define Parameters
# ----> 2 import ROOT
#       3
#
# ModuleNotFoundError: No module named 'ROOT'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_57632/999786990.py in <module>
# ----> 1 alpha = dm_21**2/dm_31**2
#
# NameError: name 'dm_31' is not defined

# %%
print(u"\u00B1")
# Out:
# ±
